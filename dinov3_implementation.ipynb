# %%
# this is for DINOv3, use this url to download the .pth file, the url will be expired soon, user can apply for a new one in the website: https://github.com/facebookresearch/dinov3?tab=readme-ov-file
import requests
import torch

url = "https://dinov3.llamameta.net/dinov3_vitb16/dinov3_vitb16_pretrain_lvd1689m-73cec8be.pth?Policy=eyJTdGF0ZW1lbnQiOlt7InVuaXF1ZV9oYXNoIjoib3U5OHlpZnZoYW84aHI5a2M1dmE1dGtlIiwiUmVzb3VyY2UiOiJodHRwczpcL1wvZGlub3YzLmxsYW1hbWV0YS5uZXRcLyoiLCJDb25kaXRpb24iOnsiRGF0ZUxlc3NUaGFuIjp7IkFXUzpFcG9jaFRpbWUiOjE3NjAwMzAzMzR9fX1dfQ__&Signature=g5%7E85PSQAMmzjARX2Vn-oq07GXPdMKTbwvJPYCWqyL3htm6NVl6bapIRVRTzl%7EBBRsGWdjQ%7EKNfp2-MhLHGncV56xqkItCXMkw8XMUnQyM051gYe8bSbQD5k0xhBi8jy2VHf1zcreHCIkMlSewqf4lOA4PfUR0R6vMaUXGJcUEBUEiDJRhJQMl6W9OO446oxfB5GXhC9CAhRClx7U9kwFJP3UZUx9SMwA1bXtgXILs%7EoPSsvXtgc1dpLwnLPoTOHoPalMKFZDLHpdsvGLBfdtJRVTcQgCYi5Yt8iXKRYOh3DSdwuMgXIb8kl5rKJvZP2UtnMVo4UuhpQAQOqSW8hzQ__&Key-Pair-Id=K15QRJLYKIFSLZ&Download-Request-ID=1121713976834311"
out_path = "dinov3_vitb16_pretrain_lvd1689m-73cec8be.pth" # named by users

with requests.get(url, stream=True) as r:
    r.raise_for_status()
    with open(out_path, "wb") as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)

print("download finished：", out_path)

# %%
# address of DINOv3 repositories and DINOv3 weights
REPO_DINOV3= "D:\cell_classification_pythonprojects\dinov3\dinov3"
WEIGHTS_DINOV3 = "D:\cell_classification_pythonprojects\My_model\dinov3_vitb16_pretrain_lvd1689m-73cec8be.pth"

model = torch.hub.load(REPO_DINOV3, 'dinov3_vitb16', source='local', weights=WEIGHTS_DINOV3)
print(model)
